# %% [markdown]
# # College of Computing and Informatics, Drexel University
# ## INFO 213: Data Science Programming II
# ---
#
# ## Project Proposal
#
# ## Project Title: Predicting Loan Approval Using Machine Learning Techniques
#
# ## Student(s): Janhi Ong, Jayda Foo
#
# ## Date: 05/20/2025
# ---

# %% [markdown]
# # List Your Team Members:
# ## 1. Member 1: Janhi Ong
# ## 2. Member 2: Jayda Foo

# %% [markdown]
# # Purpose
# ---

# %% [markdown]
# You are asked to propose a final project to practice the machine learning concepts and techniques covered in this course. Your project should include the following components:
#
# Tuesday (20 May)
#
# Dataset Selection: You must choose a dataset relevant to your interests or a specific domain. The dataset should be of sufficient size and complexity to demonstrate various machine learning techniques.
#
# Problem Definition: Define a clear problem or task to solve using machine learning techniques. It could be classification, regression, clustering, or another relevant task.
#
# Exploratory Data Analysis (EDA): You need to perform thorough EDA on the dataset to understand its characteristics, identify patterns, missing values, outliers, and potential features for modeling.
#
# Data Preprocessing: You should cleanse and preprocess the data as necessary.
#
# By Tuesday (27 May)
#
# Feature Engineering: Implement feature engineering for creating new features, transforming existing ones, or selecting relevant features.
#
# Model Selection: Experiment with different machine learning algorithms and hyperparameters.
#
# Model Evaluation: Evaluate the models using appropriate evaluation metrics
#
# Visualization and Interpretation: You should use visulization throughout EDA, modeling, and evaluation to illustrate any insights.
#
# Code and Implementation: Throughout the notebook, you must write well-structured and commented code.
#
# Documentation and Presentation: Throughout the notebook, you must add comprehensive commentary text to explain plots and code snippets. Always provide interpretations and explanations to document your analyses and results.

# %% [markdown]
# ### 1. Introduction
# ---
# *(Introduce the project and describe the objectives.)*

# %% [markdown]
# Financial institutions must assess loan applications quickly and accurately to minimize risk and ensure responsible lending. Manual review of applications can be time-consuming and inconsistent. The objective of this project is to develop a machine learning model that can accurately predict whether a loan application will be approved or rejected, based on an applicant’s financial and personal attributes.

# %% [markdown]
# ### 2. Problem Definition
# ---
# *(Define the problem that will be solved in this data analytics project.)*

# %% [markdown]
# This project addresses the problem of automated loan approval prediction using machine learning. The task is a binary classification problem, where the goal is to predict the loan_status (Approved or Rejected) based on applicant and financial features.

# %% [markdown]
# ### 3. Data Sources
# ---
# *(Describe the origin of the data sources. What is the format of the original data? How to access the data?)*

# %% [markdown]
# The dataset was provided in CSV format and contains structured data with 13 columns and 4269 rows. It includes numerical and categorical features relevant to loan decisions. The data was obtained from a publicly available source on Kaggle.
#
# Link to the dataset: https://www.kaggle.com/datasets/architsharma01/loan-approval-prediction-dataset/data

# %% [markdown]
# ### 4. The Goal(s) of the Analytics
# ---
# *(What are the expected results of the project?)*

# %% [markdown]
# The main goal of this analytics project is to build and evaluate machine learning models that accurately predict whether a loan application will be approved.
#
# Expected Results:
#
# Performing exploratory data analysis to understand data patterns and distributions
#
# Preprocessing and transforming data for model compatibility
#
# Engineering and selecting relevant features
#
# Training and comparing multiple classification models, including Perceptron, Adaline, Logistic Regression, and Random Forest
#
# Evaluating model performance using metrics such as accuracy, precision, recall, F1-score

# %% [markdown]
# ---
# (*Use the following requirements for writing your reports. DO NOT DELETE THE CELLS BELLOW*)

# %% [markdown]
# # Project Requirements

# %% [markdown]
# This final project examines the level of knowledge the students have learned from the course. The following course outcomes will be checked against the content of the report:
#
# Upon successful completion of this course, a student will be able to:
#
# Describe the key Python tools and libraries that related to a typical data analytics project.
# Identify data science libraries, frameworks, modules, and toolkits in Python that efficiently implement the most common data science algorithms and techniques.
# Apply latest Python techniques in data acquisition, transformation and predictive analytics for data science projects.
# Discuss the underlying principles and main characteristics of the most common methods and techniques for data analytics.
# Build data analytic and predictive models for real world data sets using existing Python libraries.
# ** Marking will be foucsed on both presentation and content.**
#
# Written Presentation Requirements
# The report will be judged on the basis of visual appearance, grammatical correctness, and quality of writing, as well as its contents. Please make sure that the text of your report is well-structured, using paragraphs, full sentences, and other features of well-written presentation.
#
# Technical Content:
# Is the problem well defined and described thoroughly?
# Is the size and complexity of the data set used in this project comparable to that of the example data sets used in the lectures and assignments?
# Did the report describe the charactriatics of the data?
# Did the report describe the goals of the data analysis?
# Did the analysis conduct exploratory analyses on the data?
# Did the analysis build models of the data and evaluated the performance of the models?
# Overall, what is the rating of this project?

# %% [markdown]
# # Begin Here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9e519410-87cf-48ec-963c-8b98265d1a4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e519410-87cf-48ec-963c-8b98265d1a4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
loan_df = pd.read_csv("loan_approval_dataset.csv")

loan_df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
loan_df.shape
# Out:
# (4269, 13)

# %% [markdown]
# About columns (Information provided by the owner)
# loan_id
# no_of_dependents: Number of Dependents of the Applicant
# education: Education of the Applicant (Graduate/Not Graduate)
# self_employed: Employment Status of the Applicant
# income_annum: Annual Income of the Applicant
# loan_amount: Loan Amount
# loan_term: Loan Term in Years
# cibil_score: Credit Score
# residential_assets_value
# commercial_assets_value
# luxury_assets_value
# bank_asset_value
# loan_status: Loan Approval Status (Approved/Rejected)

# %%
loan_df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %% [markdown]
# Apart from the loan_id column, the rest of the column names contain an additional space in front of the text, we will remove the space to make the column names neater

# %%
loan_df.columns = loan_df.columns.str.replace(' ', '')

# %%
loan_df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %% [markdown]
# We will remove the ID column because it does not carry any predictive or meaningful information for EDA or modeling.

# %%
loan = loan_df.drop(['loan_id'], axis=1)
loan.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
loan.shape
# Out:
# (4269, 12)

# %% [markdown]
# #Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Loan and status amount

# %%
# Distribution of loan amount
sns.boxplot(loan['loan_amount'])
plt.title("Loan Amount")
plt.xlabel("Loan Amount")
plt.show()

# %%
# Relationship between loan amount and loan status
sns.histplot(loan, x='loan_amount', hue='loan_status')
plt.title("Does loan status relate to the loan amount?")
plt.xlabel("Loan Amount")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# From the bar chart, we can see that both approved and rejected loans have the same trends based on the different loan amounts. However, we haven't seen a strong relationship between the loan status and the loan amount in the histogram.

# %%
# Relationship between Loan Status, Loan Amount, and Annual Income
sns.scatterplot(x=loan['income_annum'], y= loan['loan_amount'], hue=loan['loan_status'])
plt.title("Loan Status, Loan Amount, Annual Income")
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.show()

# %% [markdown]
# There are some interesting insights we have seen over the above figure:
#
# 1. When annual income increases, the loan amount tends to increase. But the annual income doesn't show an obvious trend with the loan status.
# 2. In this dataset, the applicants who have the lower annual income have a narrow range in loan amounts. Vise Versa, the applicants who have the higher lower annual income have a wider range in the loan amounts. Besides that the lenders will only accept the loan amount that aligns with the annual income in order to insure the applicants have ability to pay the loan back, it is easy to imagine the applicants who have higher annual income have more flexibility on the amount of the loan, whatever for themselves or for the lenders.
# 3. In this dataset, the applicants who has highest annual income has been approved when they apply for the highest loan amount (see the upper right corner of the figure), but at the same time, the applicants who have the highest annual income have chances of being rejected when they apply lower loan amount (see the middle right of the figure/lower right of the triangle). It can be caused by different lenders and other conditions of the applicants.

# %% [markdown]
# ### 2. Credit Score

# %%
# Relationship between Loan Status, Loan Amount, and Credit Score
sns.scatterplot(x=loan['cibil_score'], y= loan['loan_amount'], hue=loan['loan_status'])
plt.title("Loan Status, Loan Amount, Credit Score")
plt.xlabel("Credit Score")
plt.ylabel("Loan Amount")
plt.show()

# %% [markdown]
# From the plot, we can see the credit scores around 540 - 550 separate the loan status into two parts in a very clear way. In the other words, the loan status is highly related to the credit score. It is also interesting to see the credit score that separates the loan status is not 579 which is the highest score of the "poor" credit score. In the other words, the poor credit scores which are above 540 - 550 still have a good chance of being approved by loan lenders.

# %% [markdown]
# However, we also notice a puzzling trend: some of the applicants with high credit scores (above 740) were still rejected. Few of them have only applied for a small amount of the loan which is below the median amount. What is the reason?

# %%
loan.loc[(loan['cibil_score'] > 740) & (loan['loan_status'] ==' Rejected')].sort_values(['cibil_score'], ascending= False)
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 559                  2       Graduate           Yes        200000
# 3527                 0       Graduate            No       1800000
# 911                  0       Graduate           Yes       1300000
# 3213                 1   Not Graduate           Yes       4300000
# 236                  3       Graduate           Yes        900000
# 4099                 3       Graduate            No       8700000
# 1446                 1       Graduate            No        300000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 559        500000          6          885                   -100000
# 3527      6900000         10          853                    900000
# 911       4800000          4          835                    500000
# 3213     16300000         14          792                    400000
# 236       3500000          4          770                    700000
# ...

# %% [markdown]
# By creating the subset, we have more than 5 applicants with more than 740 credit scores, their applications were rejected.
# In order to discover more reasons, there are 4 features that take my attention, they are residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value.

# %% [markdown]
# ### 3. Residential assets, Commercial assets, Luxury assets, Bank asset

# %%
fig,axes = plt.subplots(2, 2, figsize = (8, 6))

sns.histplot(loan, x = 'residential_assets_value', hue = 'loan_status', ax = axes[0,0])
axes[0,0].set_xlabel("Residential Assets Value")
axes[0,0].set_ylabel("Count")

sns.histplot(loan, x = 'commercial_assets_value', hue = 'loan_status', ax = axes[1,0])
axes[1,0].set_xlabel("Commercial Assets Value")
axes[1,0].set_ylabel("Count")

sns.histplot(loan, x = 'luxury_assets_value', hue = 'loan_status', ax = axes[0,1])
axes[0,1].set_xlabel("Luxury Assets Value")
axes[0,1].set_ylabel("Count")

sns.histplot(loan, x = 'bank_asset_value', hue = 'loan_status', ax = axes[1,1])
axes[1,1].set_xlabel("Bank Assets Value")
axes[1,1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# The same as the loan amount, we are not able to see the clear trends between those asset values and the loan status, we have to do something else and see what those asset values are.

# %% [markdown]
# Let's create a subset and get to know the correlation scores between those 4 asset values and other variables.

# %%
loan_asset = loan[['residential_assets_value', 'commercial_assets_value',
       'luxury_assets_value', 'bank_asset_value', 'no_of_dependents', 'education', 'self_employed',
       'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
       'loan_status']]

loan_asset_numeric = loan_asset.select_dtypes(include=['number'])

loan_asset_corr = loan_asset_numeric.corr()

# %%
sns.heatmap(loan_asset_corr, annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Now we can see some insights through the heatmap:
#
# All the asset values have moderate to strong positive linear relationships with the annual income. As the applicants who have more annual income tend to have more flexibility on purchasing the properties with higher asset values especially the luxury assets value.

# %%
fig,axes = plt.subplots(2, 2, figsize = (8, 6))

sns.scatterplot(loan, x = 'residential_assets_value', y= 'income_annum', hue = 'loan_status', ax = axes[0,0])
axes[0,0].set_xlabel("Residential Assets Value")

sns.scatterplot(loan, x = 'commercial_assets_value', y= 'income_annum', hue = 'loan_status',ax = axes[1,0])
axes[1,0].set_xlabel("Commercial Assets Value")

sns.scatterplot(loan, x = 'luxury_assets_value', y= 'income_annum', hue = 'loan_status',ax = axes[0,1])
axes[0,1].set_xlabel("Luxury Assets Value")

sns.scatterplot(loan, x = 'bank_asset_value', y= 'income_annum', hue = 'loan_status',ax = axes[1,1])
axes[1,1].set_xlabel("Bank Assets Value")

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see, both of residential_assets_value, commercial_assets_value create right triangles on the scatter plots, cutting the plot into two sections. This indicates that the relationship between annual income and these asset values might have some sort of threshold effect. For example, once the asset value reaches a certain point, the annual income tends to increase significantly.
# The obtuse triangles you're seeing for luxury_assets_value, bank_asset_value suggest have a different type of relationship. The smaller triangle for luxury assets value compared to bank asset value might indicate that while there's a strong correlation between luxury assets value and annual income, there's a higher variability in annual income for any given luxury assets value. In other words, luxury assets might be a good indicator of higher annual income, but there are exceptions.

# %% [markdown]
# ### 4. Education

# %%
plt.figure(figsize = (6,4))
sns.countplot(loan, x='education', hue='loan_status')
plt.xlabel("Education")
plt.title("Counts for education")

plt.show()

# %% [markdown]
# The counts based on different education status are approximately the same.
# In addition, on the description page of this dataset, "education: Education of the Applicant (Graduate/Not Graduate)". We have to put a question mark here, if the education means high-school education or college education?
# Then, we are curious about whether education affects any of the variables here.

# %%
education = loan.groupby(["education"], as_index=False).agg(
    count_by_education=("education", "count"),
    median_annual_income=("income_annum", "median"),
    average_loan_amount=("loan_amount", "mean"),
    average_credit_score = ("cibil_score", "mean"),
    average_loan_term = ("loan_term", "mean"),
    avg_residential_value = ('residential_assets_value', "mean"),
    avg_commerical_value = ( 'commercial_assets_value', "mean"),
    avg_luxury_value = ( 'luxury_assets_value', "mean"),
    avg_bank_value = ('bank_asset_value', "mean")

).round(2).reset_index(drop=True)

education
# Out:
#        education  count_by_education  median_annual_income  \
# 0       Graduate                2144             5100000.0
# 1   Not Graduate                2125             5000000.0
#
#    average_loan_amount  average_credit_score  average_loan_term  \
# 0          15229151.12                599.14              10.85
# 1          15036894.12                600.74              10.95
#
#    avg_residential_value  avg_commerical_value  avg_luxury_value  \
# 0             7543376.87            4943610.07       15239319.03
# 1             7401223.53            5002964.71       15012282.35
#
#    avg_bank_value
# 0      5007182.84
# 1      4945929.41

# %% [markdown]
# By creating a sub-table, we can say there are no significant differences between the education and other variables in this dataset.

# %% [markdown]
# ### 5. Self-employed

# %%
self_employed = loan.groupby(["self_employed"], as_index=False).agg(
    count=("education", "count"),
    median_annual_income=("income_annum", "median"),
    average_loan_amount=("loan_amount", "mean"),
    average_credit_score = ("cibil_score", "mean"),
    average_loan_term = ("loan_term", "mean"),
    avg_residential_value = ('residential_assets_value', "mean"),
    avg_commerical_value = ( 'commercial_assets_value', "mean"),
    avg_luxury_value = ( 'luxury_assets_value', "mean"),
    avg_bank_value = ('bank_asset_value', "mean")

).round(2).reset_index(drop=True)

self_employed
# Out:
#   self_employed  count  median_annual_income  average_loan_amount  \
# 0            No   2119             5100000.0          15120245.40
# 1           Yes   2150             5100000.0          15146465.12
#
#    average_credit_score  average_loan_term  avg_residential_value  \
# 0                600.78              10.88             7432373.76
# 1                599.10              10.92             7512279.07
#
#    avg_commerical_value  avg_luxury_value  avg_bank_value
# 0            5052713.54       15085842.38       4977395.0
# 1            4894744.19       15166186.05       4976000.0

# %% [markdown]
# Same thing as the self_employed - there are no significant differences between the self_employed and other variables in this dataset.

# %% [markdown]
# Even though we didn't find the strong relationship between no_of_dependent, education, self_employed and other variables in this dataset, we are still willing to discover more by using different techniques.

# %% [markdown]
# #Feature Engineering / Standardize

# %% [markdown]
# We are now proceeding to the construct stage, which is the step for building a machine learning model. Before we start, we need to do some extra steps to make the variables ready for the following steps. We will need to convert our categorical columns (education, self_employed, loan_status) into numerical values for the machine learning model

# %%
# Strip spaces from all object (string) columns
loan = loan.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

loan_dummies = pd.get_dummies(loan, drop_first=False)
print(loan_dummies.dtypes)
# Out:
# no_of_dependents            int64
# income_annum                int64
# loan_amount                 int64
# loan_term                   int64
# cibil_score                 int64
# residential_assets_value    int64
# commercial_assets_value     int64
# luxury_assets_value         int64
# bank_asset_value            int64
# education_Graduate           bool
# education_Not Graduate       bool
# self_employed_No             bool
# self_employed_Yes            bool
# loan_status_Approved         bool
# loan_status_Rejected         bool
# dtype: object

# %%
#Keeping the columns that we want
loan_dummies = loan_dummies[[
    'no_of_dependents',
    'income_annum',
    'loan_amount',
    'loan_term',
    'cibil_score',
    'residential_assets_value',
    'commercial_assets_value',
    'luxury_assets_value',
    'bank_asset_value',
    'education_Graduate',
    'self_employed_Yes',
    'loan_status_Approved'
]]

# %%
loan_dummies.rename(columns={
    'education_Graduate': 'education',
    'self_employed_Yes': 'self_employed',
    'loan_status_Approved': 'loan_status'
}, inplace=True)

print(loan_dummies.dtypes)
# Out:
# no_of_dependents            int64
# income_annum                int64
# loan_amount                 int64
# loan_term                   int64
# cibil_score                 int64
# residential_assets_value    int64
# commercial_assets_value     int64
# luxury_assets_value         int64
# bank_asset_value            int64
# education                    bool
# self_employed                bool
# loan_status                  bool
# dtype: object

# %% [markdown]
# Let's check the correlation score again!

# %%
loan_corr = loan_dummies.corr()
plt.figure(figsize=(9,9))
sns.heatmap(loan_corr, annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Over the heatmap above, we can now see the variable that affects the loan_status the most is cibil_score.
# We also proved there is no variable that has a linear relationship with the education and self_employed.
# As we already mentioned over previous sections, there are strong linear relationship between income_annum & loan_amount, luxury_assets_value & income_annum, bank_asset_value & income_annum and luxury_assets_value & bank_asset_value

# %%
# all features (independent variables)
X = loan_dummies.drop('loan_status', axis=1)

# target variable (1 = Approved, 0 = Rejected)
y = loan_dummies['loan_status']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3415, 11), (3415,), (854, 11), (854,))

# %% [markdown]
# We perfectly separate the train and test sets with 80:20 ratio in the overall dataset.

# %% [markdown]
# #Model Training and Hyperparamter Tuning

# %% [markdown]
# We will now move on to training and tuning the model. We will be training the data with 4 different models: Perceptron, Adaline, Logistic Regression and Random Forest. Data will be scaled with MinMaxScalar for training with
# Perceptron, Adaline, Logistic Regression.

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Perceptron

# %%
class PerceptronCorrect(object):
    """Perceptron classifier.

    Parameters
    ------------
    eta : float
      Learning rate (between 0.0 and 1.0)
    epochs : int
      Passes over the training dataset.
    random_state : int
      Random number generator seed for random weight
      initialization.

    Attributes
    -----------
    w_ : 1d-array
      Weights after fitting.
    b_: 1d-array
      bias after fitting
    errors_ : list
      Number of misclassifications (updates) in each epoch.

    """
    def __init__(self, eta=0.01, epochs=50, random_state=1):
        self.eta = eta
        self.epochs = epochs
        self.random_state = random_state


    def predict(self, X):
        """Return class label after unit step"""

        # compute the z values

        z = np.dot(X, self.w_) + self.b_

        return np.where(z >= 0.0, 1, 0)

    def fit(self, X, y):
        """Fit training data.

        Parameters
        ----------
        X : {array-like}, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.

        Returns
        -------
        self : object

        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size = X.shape[1])
        self.b_ = np.float64(0.)

        self.errors_ = []

        for _ in range(self.epochs):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))
                self.w_ += update * xi
                self.b_ += update

                errors += int(update != 0.0)

            self.errors_.append(errors)

        return self

# %%
ppn = PerceptronCorrect(eta=0.1, epochs=50)
ppn.fit(X_train_scaled, y_train)

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of Misclassifications')
plt.title('Perceptron Learning Progress')
plt.show()

# %%
from sklearn.metrics import accuracy_score

y_pred_ppn = [ppn.predict(xi) for xi in X_test_scaled]
acc_ppn = accuracy_score(y_test, y_pred_ppn)
print(f'Accuracy Score (Perceptron): {acc_ppn:.3f}')
# Out:
# Accuracy Score (Perceptron): 0.849

# %% [markdown]
# Hyperparameter Tuning:

# %%
etas = np.arange(0.1, 1.1, 0.1)
accuracy_list = []

for eta in etas:
    ppn = PerceptronCorrect(eta=eta, epochs=50)
    ppn.fit(X_train_scaled, y_train)
    y_pred = [ppn.predict(xi) for xi in X_test_scaled]
    acc = accuracy_score(y_test, y_pred)
    accuracy_list.append(acc)

# Plot eta vs. accuracy
plt.figure(figsize=(8, 5))
plt.plot(etas, accuracy_list, marker='o')
plt.xlabel('Learning Rate (eta)')
plt.ylabel('Validation Accuracy')
plt.title('Perceptron Accuracy vs. Learning Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# The perceptron reached its highest classification accuracy at η = 0.2. Although η values like 0.8 and 1.0 also performed well, 0.2 showed more stable results across runs, making it a reliable choice for the learning rate.

# %%
ppn = PerceptronCorrect(eta=0.2, epochs=50)
ppn.fit(X_train_scaled, y_train)

y_pred_ppn = [ppn.predict(xi) for xi in X_test_scaled]
acc_ppn = accuracy_score(y_test, y_pred_ppn)
print(f'Accuracy Score (Perceptron): {acc_ppn:.3f}')
# Out:
# Accuracy Score (Perceptron): 0.888

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_ppn)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix (Perceptron)")
plt.grid(False)
plt.show()

# %% [markdown]
# The confusion matrix shows how well the logistic regression model predicted loan approvals (1) and rejections (0):
#
# 289 loans were correctly predicted as rejected (True Negatives).
#
# 469 loans were correctly predicted as approved (True Positives).
#
# 29 loans were incorrectly predicted as approved but were actually rejected (False Positives).
#
# 67 loans were incorrectly predicted as rejected but were actually approved (False Negatives).
#
# This means the model made only a small number of mistakes, and majority of the predictions were accurate.

# %%
from sklearn.metrics import classification_report

print("Classification Report (Perceptron):")
print(classification_report(y_test, y_pred_ppn))
# Out:
# Classification Report (Perceptron):
#               precision    recall  f1-score   support
#
#        False       0.81      0.91      0.86       318
#         True       0.94      0.88      0.91       536
#
#     accuracy                           0.89       854
#    macro avg       0.88      0.89      0.88       854
# weighted avg       0.89      0.89      0.89       854

# %% [markdown]
# Before moving on, we will rescale the the dataset with Standard Scaler instead of MinMaxScaler because Adaline and Logistic Regression benefits from centered, standardized data

# %%
from sklearn.preprocessing import StandardScaler

scaler_std = StandardScaler()
X_train_std = scaler_std.fit_transform(X_train)
X_test_std = scaler_std.transform(X_test)

# %% [markdown]
# ##Adaline Model

# %%
class AdalineGD(object):
    """ADAptive LInear NEuron classifier.

    Parameters
    ------------
    eta : float
      Learning rate (between 0.0 and 1.0)
    epochs : int
      Passes over the training dataset.
    random_state : int
      Random number generator seed for random weight
      initialization.


    Attributes
    -----------
    w_ : 1d-array
      Weights after fitting.
    b_ : 1d-array
      bias after fitting.
    cost_ : list
      Sum-of-squares cost function value in each epoch.

    """
    def __init__(self, eta=0.01, epochs=50, random_state=1):
        self.eta = eta
        self.epochs = epochs
        self.random_state = random_state

    def activation(self, z):
        """Compute linear activation"""
        return z

    def predict(self, X):
        """Return class label after unit step"""

        # compute the z values;
        z = np.dot(X, self.w_) + self.b_

        return np.where(self.activation(z) >= 0.0, 1, 0)

    def fit(self, X, y):
        """ Fit training data.

        Parameters
        ----------
        X : {array-like}, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.

        Returns
        -------
        self : object

        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size = X.shape[1])
        self.b_ = np.float64(0.)

        self.cost_ = []

        for i in range(self.epochs):
            # compute the z values
            z = np.dot(X, self.w_) + self.b_

            # Please note that the "activation" method has no effect
            # in the code since it is simply an identity function. We
            # could write `output = z` directly instead.
            # The purpose of the activation is more conceptual, i.e.,
            # in the case of logistic regression (as we will see later),
            # we could change it to
            # a sigmoid function to implement a logistic regression classifier.
            output = self.activation(z)
            errors = (y - output)

            self.w_ += self.eta * X.T.dot(errors)
            self.b_ += self.eta * errors.sum()

            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)

        return self

# %%
adaline = AdalineGD(epochs=30, eta=0.0001)
adaline.fit(X_train_std, y_train)

# %%
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class examples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0],
                    y=X[y == cl, 1],
                    alpha=0.8,
                    c=colors[idx],
                    marker=markers[idx],
                    label=cl,
                    edgecolor='black')

# %%
y_pred_adaline = adaline.predict(X_test_std)
from sklearn.metrics import accuracy_score
acc_adaline_baseline = accuracy_score(y_test, y_pred_adaline)
print(f"Accuracy (Adaline before tuning): {acc_adaline_baseline:.3f}")
# Out:
# Accuracy (Adaline before tuning): 0.670

# %% [markdown]
# The initial Adaline model achieved an accuracy of 67.1%, indicating a modest baseline performance. While it shows some learning, there's clear room for improvement through hyperparameter tuning.

# %%
# Plot the learning curve of the Adaline model

plt.plot(range(1, len(adaline.cost_) + 1), np.log10(adaline.cost_), marker='o')
plt.xlabel('Epochs')
plt.ylabel('Log10(Sum-squared-error)')
plt.title('Adaline - Learning Curve')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Range of eta values to test
etas = np.arange(0.0001, 0.0003, 0.00002)

accuracy_list = []

for eta in etas:
    model = AdalineGD(eta=eta, epochs=50)
    model.fit(X_train_std, y_train)
    y_pred = model.predict(X_test_std)
    acc = accuracy_score(y_test, y_pred)
    accuracy_list.append(acc)

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(etas, accuracy_list, marker='o')
plt.xlabel('Learning Rate (eta)')
plt.ylabel('Validation Accuracy')
plt.title('Adaline Accuracy vs. Learning Rate (epochs = 50)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The graph shows how the Adaline model's validation accuracy changes with different learning rates (eta) over 50 epochs. We observe that the model performs best at lower learning rates (around 0.0001–0.000125), achieving an accuracy close to 0.675. However, as the learning rate increases beyond 0.00015, the accuracy sharply drops and plateaus around 0.49, indicating that a high learning rate causes the model to converge poorly or diverge entirely.

# %%
# Initialize and train Adaline
adaline = AdalineGD(eta=0.000125, epochs=50)
adaline.fit(X_train_std, y_train)

# Predict on test set
y_pred_adaline = adaline.predict(X_test_std)

# Evaluate accuracy
acc_adaline = accuracy_score(y_test, y_pred_adaline)
print(f'Accuracy Score (Adaline) after hyperparameter training: {acc_adaline:.3f}')
# Out:
# Accuracy Score (Adaline) after hyperparameter training: 0.671

# %% [markdown]
# After tuning the learning rate and increasing the number of epochs, the Adaline model achieved an accuracy of 67.1%, which is the same as the initial baseline. This suggests that the chosen hyperparameter adjustments had little impact and Adaline may not be well-suited for this dataset, possibly due to its linear nature and sensitivity to feature relationships.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Compute the confusion matrix
cm_adaline = confusion_matrix(y_test, y_pred_adaline)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm_adaline)
disp.plot()
plt.title("Confusion Matrix (Adaline)")
plt.grid(False)
plt.show()

# %% [markdown]
# This confusion matrix reveals that the Adaline model performs poorly in identifying class 0 (only 37 out of 318 were correctly predicted), while it predicts class 1 extremely well (536 out of 536 correct). The model exhibits a strong bias toward predicting class 1, likely due to class imbalance or insufficient learning capacity. This indicates Adaline is not suitable for this dataset in its current form.

# %%
from sklearn.metrics import classification_report

print("Classification Report (Adaline):")
print(classification_report(y_test, y_pred_adaline))
# Out:
# Classification Report (Adaline):
#               precision    recall  f1-score   support
#
#        False       1.00      0.12      0.21       318
#         True       0.66      1.00      0.79       536
#
#     accuracy                           0.67       854
#    macro avg       0.83      0.56      0.50       854
# weighted avg       0.78      0.67      0.57       854

# %% [markdown]
# The classification report confirms that Adaline heavily favors predicting the True class, achieving perfect recall (1.00) but at the cost of very poor recall (0.12) and f1-score (0.21) for the False class. This imbalance skews the overall accuracy to 67%, but the macro and weighted averages reveal weak overall performance, especially in terms of fairness across classes. The model is clearly not generalizing well and struggles to capture patterns from the minority class.

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Step 1: Instantiate the logistic regression model
log_reg = LogisticRegression(C=100.0, penalty='l2', random_state=1, solver='lbfgs')

# Step 2: Fit the model on the standardized training data
log_reg.fit(X_train_std, y_train)

# Step 3: Predict on standardized validation data
y_pred_lr = log_reg.predict(X_test_std)

# Step 4: Evaluate the model
acc_log = accuracy_score(y_test, y_pred_lr)
print(f'Classification Accuracy (Logistic Regression): {acc_log:.3f}')
# Out:
# Classification Accuracy (Logistic Regression): 0.904

# %% [markdown]
# For hyperparameter tuning, we will create a GridSearchCV object with the logistic regression pipeline, its parameter grid, and 5-fold cross validation.

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, cross_val_score
import numpy as np

pipe_lr = make_pipeline(
    StandardScaler(),
    LogisticRegression(random_state=1)
)


param_grid_lr = {
    'logisticregression__C': [0.01, 0.1, 1.0, 10.0, 100.0],
    'logisticregression__solver': ['lbfgs', 'liblinear']
}

# GridSearchCV with 5-fold cross-validation
gs_lr = GridSearchCV(estimator=pipe_lr,
                     param_grid=param_grid_lr,
                     scoring='accuracy',
                     cv=5,
                     refit=True,
                     n_jobs=-1)

gs_lr.fit(X_train, y_train)

print(f"Best Cross-Validation Accuracy: {gs_lr.best_score_:.3f}")
print("Best Parameters:", gs_lr.best_params_)
# Out:
# Best Cross-Validation Accuracy: 0.923
# Best Parameters: {'logisticregression__C': 0.01, 'logisticregression__solver': 'liblinear'}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Get the best model after GridSearchCV
best_lr = gs_lr.best_estimator_

# Predict on the test set
y_pred_lr = best_lr.predict(X_test)

# Compute confusion matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm_lr)
disp.plot()
plt.title("Confusion Matrix (Logistic Regression)")
plt.grid(False)
plt.show()

# %% [markdown]
# The confusion matrix shows how well the logistic regression model predicted loan approvals (1) and rejections (0):
#
# 290 loans were correctly predicted as rejected (True Negatives).
#
# 494 loans were correctly predicted as approved (True Positives).
#
# 28 loans were incorrectly predicted as approved but were actually rejected (False Positives).
#
# 42 loans were incorrectly predicted as rejected but were actually approved (False Negatives).
#
# This means the model made only a small number of mistakes, and most of the predictions were accurate.

# %%
from sklearn.metrics import classification_report

print("Classification Report (Logistic Regression):")
print(classification_report(y_test, gs_lr.predict(X_test)))
# Out:
# Classification Report (Logistic Regression):
#               precision    recall  f1-score   support
#
#        False       0.87      0.91      0.89       318
#         True       0.95      0.92      0.93       536
#
#     accuracy                           0.92       854
#    macro avg       0.91      0.92      0.91       854
# weighted avg       0.92      0.92      0.92       854

# %% [markdown]
# The classification report shows how well the logistic regression model predicted loan approvals and rejections. For approved loans (“True”), it achieved a precision of 0.95, meaning 95% of predicted approvals were actually correct, and a recall of 0.92, meaning it correctly identified 92% of actual approvals. The F1-score, which balances both precision and recall, was 0.93. For rejected loans (“False”), the F1-score was 0.89. These strong scores suggest the model is effective at minimizing both false positives and false negatives, making it reliable for loan classification tasks based on the dataset used.

# %% [markdown]
# Random Forest (DO NOT SCALE DATA)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# 1. Train basic model
rf = RandomForestClassifier(random_state=1)
rf.fit(X_train, y_train)

# 2. Predict
y_pred_rf = rf.predict(X_test)

# 3. Evaluate
acc_rf = accuracy_score(y_test, y_pred_rf)
print(f"Accuracy Score (Random Forest): {acc_rf:.3f}")
# Out:
# Accuracy Score (Random Forest): 0.981

# %% [markdown]
# An accuracy score of 0.981 from the Random Forest model indicates exceptional performance, correctly classifying 98.1% of the test samples. This suggests that the model has effectively learned the underlying patterns in the dataset and handles both classes well. Compared to Adaline and other models, Random Forest clearly outperforms in terms of predictive accuracy and robustness.

# %% [markdown]
# # Hyperparameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
}

# Grid search
gs_rf = GridSearchCV(RandomForestClassifier(random_state=1),
                     param_grid=param_grid_rf,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1,
                     refit=True)

gs_rf.fit(X_train, y_train)

print(f"Best CV Accuracy (RF): {gs_rf.best_score_:.3f}")
print("Best Parameters:", gs_rf.best_params_)

# Predict using best estimator
y_pred_rf_best = gs_rf.predict(X_test)

# Final evaluation
acc_rf_best = accuracy_score(y_test, y_pred_rf_best)
print(f"Test Accuracy (Random Forest - Tuned): {acc_rf_best:.3f}")

# Confusion matrix + classification report
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred_rf_best)).plot()
plt.title("Confusion Matrix (Random Forest - Tuned)")
plt.grid(False)
plt.show()
# Out:
# Best CV Accuracy (RF): 0.980
# Best Parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# Test Accuracy (Random Forest - Tuned): 0.981

# %% [markdown]
# This confusion matrix for the tuned Random Forest model shows near-perfect classification, with only 16 total misclassifications out of 854 instances. It correctly identifies both classes with high precision and recall — only 10 false positives and 6 false negatives. This indicates the model is highly balanced and accurate, making it the best-performing model so far.

# %%
print("Classification Report (Random Forest - Tuned):")
print(classification_report(y_test, y_pred_rf_best))
# Out:
# Classification Report (Random Forest - Tuned):
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97       318
#         True       0.98      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %% [markdown]
# The classification report for the tuned Random Forest model demonstrates outstanding and balanced performance across both classes, with precision, recall, and F1-scores all ranging from 0.98 to 0.99. The model achieves a high overall test accuracy of 98.1% while maintaining fairness between the minority and majority classes. However, given the perfect training accuracy of 100%, there is a potential sign of overfitting. To confirm this, we conducted an overfitting check by comparing training and test accuracies, which revealed only a slight performance gap, indicating mild but acceptable overfitting.

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predict on training and test data
y_train_pred_rf = rf.predict(X_train)
y_test_pred_rf = rf.predict(X_test)

# Accuracy
acc_train_rf = accuracy_score(y_train, y_train_pred_rf)
acc_test_rf = accuracy_score(y_test, y_test_pred_rf)

print(f'Random Forest Training Accuracy: {acc_train_rf:.3f}')
print(f'Random Forest Test Accuracy:     {acc_test_rf:.3f}')

# Optional: Confusion Matrix & Classification Report
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred_rf))
print("Confusion Matrix (Test Set):")
print(confusion_matrix(y_test, y_test_pred_rf))
# Out:
# Random Forest Training Accuracy: 1.000
# Random Forest Test Accuracy:     0.981
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97       318
#         True       0.98      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
#
# Confusion Matrix (Test Set):
# [[308  10]
#  [  6 530]]

# %% [markdown]
# The Random Forest model achieved outstanding performance, with a training accuracy of 100% and a test accuracy of 98.1%. This suggests that the model fits the training data perfectly while still generalizing very well to unseen examples. The small gap between training and test accuracy indicates only mild overfitting, which is common and generally acceptable in ensemble methods like Random Forests. The classification report reinforces this, showing high precision and recall across both classes, and the confusion matrix reveals only a few misclassifications. To better understand why the model performs so well and whether any features disproportionately drive this performance, we examined the feature importances to identify which variables most significantly influence the model’s predictions.

# %% [markdown]
# # Feature Importance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'rf' is your trained RandomForestClassifier
# and X_train is a DataFrame (not just a NumPy array)
importances = rf.feature_importances_
feature_names = X_train.columns  # Only works if X_train is a DataFrame

# Create a DataFrame for easier viewing
feat_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Display table
print(feat_importance_df)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(feat_importance_df['Feature'], feat_importance_df['Importance'], color='teal')
plt.gca().invert_yaxis()  # Highest importance at top
plt.title('Feature Importance (Random Forest)')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.show()
# Out:
#                      Feature  Importance
# 4                cibil_score    0.816268
# 3                  loan_term    0.060086
# 2                loan_amount    0.028924
# 1               income_annum    0.017729
# 5   residential_assets_value    0.017531
# 7        luxury_assets_value    0.016559
# 6    commercial_assets_value    0.015117
# 8           bank_asset_value    0.013953
# 0           no_of_dependents    0.008598
# 10             self_employed    0.002768
# 9                  education    0.002466

# %% [markdown]
# In our analysis, we found that cibil_score stands out as the most important factor influencing the model's predictions. One possible reason for this prominence could be that cibil_score has a notable relationship with the target variable loan_status. However, it's important to note that correlation doesn't imply causation. While cibil_score plays a crucial role in the model's predictions, it's important to remember that our model identifies patterns and associations in the data. The importance of a feature doesn't necessarily mean it directly causes the predicted outcomes.In the context of our problem, cibil_score corresponds to credit scores. We should also consider that other factors, interactions between features, and potential noise in the data can influence these findings. Therefore, a holistic understanding of the model's behavior requires taking these aspects into account. The insights from the feature importance analysis can guide us in making informed decisions and refining our strategies. It's important to interpret these findings alongside other domain knowledge and analysis.

# %% [markdown]
# #Final Evaluation

# %%
from sklearn.metrics import accuracy_score

# For Perceptron
y_pred_ppn = [ppn.predict(xi) for xi in X_test_scaled]
acc_ppn = accuracy_score(y_test, y_pred_ppn)

# For Logistic Regression
y_pred_lr = gs_lr.predict(X_test)
acc_lr = accuracy_score(y_test, y_pred_lr)

# Adaline
y_pred_adaline = adaline.predict(X_test_std)
acc_adaline = accuracy_score(y_test, y_pred_adaline)

# For Random Forest
y_pred_rf = gs_rf.predict(X_test)
acc_rf = accuracy_score(y_test, y_pred_rf)


# Print final comparison
print("Final Model Accuracy Comparison:")
print(f"Perceptron: {acc_ppn:.3f}")
print(f"Logistic Regression: {acc_lr:.3f}")
print(f"Adaline:              {acc_adaline:.3f}")
print(f"Random Forest:        {acc_rf:.3f}")
# Out:
# Final Model Accuracy Comparison:
# Perceptron: 0.888
# Logistic Regression: 0.918
# Adaline:              0.671
# Random Forest:        0.981

# %% [markdown]
# Based on the final model accuracy comparison, Random Forest outperformed all other models in predicting loan approval outcomes, achieving a remarkable accuracy of 98.1%. Logistic Regression followed with a strong 91.8%, outperforming the Perceptron, which reached 88.8%. The Adaline model had the lowest performance, with only 67.1% accuracy, suggesting it struggled to capture the underlying patterns in the data. Overall, Random Forest proved to be the most effective model, showing superior generalization to unseen examples.
